# %%
pip install textblob
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 624.3/624.3 kB 2.1 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 1.9 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.8.1
#     Uninstalling nltk-3.8.1:
#       Successfully uninstalled nltk-3.8.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
python -m textblob.download_corpora
# Out:
#   Cell In[3], line 1
#     python -m textblob.download_corpora
#               ^
# SyntaxError: invalid syntax

# %%
from textblob import TextBlob
blob = TextBlob("I love learning python and Gen AI . what a great tools")

# %%
print(blob.words)
# Out:
# ['I', 'love', 'learning', 'python', 'and', 'Gen', 'AI', 'what', 'a', 'great', 'tools']

# %%
print(blob.sentences)
# Out:
# [Sentence("I love learning python and Gen AI ."), Sentence("what a great tools")]

# %%
print(blob.sentiment)
# Out:
# Sentiment(polarity=0.65, subjectivity=0.675)

# %%
print(blob.tags)
# Out:
# [('I', 'PRP'), ('love', 'VBP'), ('learning', 'VBG'), ('python', 'NN'), ('and', 'CC'), ('Gen', 'NNP'), ('AI', 'NNP'), ('what', 'WP'), ('a', 'DT'), ('great', 'JJ'), ('tools', 'NNS')]

# %%
print(blob.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(blob.detect_language())
#
# AttributeError: 'TextBlob' object has no attribute 'detect_language'

# %%
blob1 = TextBlob("I love learning python and Gen AI . what a greaaat tools").correct().lower()
print(blob1)
# Out:
# i love learning patron and men of . what a great tools
