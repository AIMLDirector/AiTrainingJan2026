# %%
import spacy

# %%
import spacy 
nlp = spacy.load("en_core_web_sm")

doc = nlp("NASA awarded Elon Musk’s SpaceX a $2.9 billion contract to build the lunar lander.")
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# NASA NASA PROPN NNP nsubj XXXX True False
# awarded award VERB VBD ROOT xxxx True False
# Elon Elon PROPN NNP compound Xxxx True False
# Musk Musk PROPN NNP dative Xxxx True False
# ’s ’s PART POS case ’x False True
# SpaceX SpaceX PROPN NNP dative XxxxxX True False
# a a DET DT det x True True
# $ $ SYM $ quantmod $ False False
# 2.9 2.9 NUM CD compound d.d False False
# billion billion NUM CD nummod xxxx True False
# contract contract NOUN NN dobj xxxx True False
# to to PART TO aux xx True True
# build build VERB VB acl xxxx True False
# the the DET DT det xxx True True
# lunar lunar ADJ JJ amod xxxx True False
# lander lander NOUN NN dobj xxxx True False
# . . PUNCT . punct . False False
